# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(include='number').head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
#your code here- categorical variable
titanic.select_dtypes(exclude='number').head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here

plt.style.use('classic')
plt.rcParams["figure.figsize"] = (12,6)

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
titanic['Age'].hist()

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
plt.subplot(1,3,1)
titanic['Age'].hist(bins=10)
plt.subplot(1,3,2)
titanic['Age'].hist(bins=20)
plt.subplot(1,3,3)
titanic['Age'].hist(bins=50)

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
cuantas más bins más dificil de visualizar
# Out:
#   File "<ipython-input-70-868198f6f6ab>", line 2
#     cuantas más bins más dificil de visualizar
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.distplot(titanic['Age'])

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
sns.countplot(titanic['Gender'])

# %%
# your code here- 2nd way
titanic_gender=titanic['Gender'].value_counts()
titanic_gender.plot(kind='bar')

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
titanic_Pclass=titanic['Pclass'].value_counts()
titanic_Pclass.plot(kind='bar')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
plt.boxplot(titanic['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x133eb1780>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x133eb1e48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x133eb1390>],
#  'medians': [<matplotlib.lines.Line2D at 0x133ebd518>],
#  'fliers': [<matplotlib.lines.Line2D at 0x133ebd860>],
#  'means': []}

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
'''
La mediana se situa en 28 años aprox (la mitad tenía más de 28 y la otra mitad por debajo de 28 años)
Inter-quartile: el 50% de las personas tenían entre 22 y 38
Upper quartile: el 75% tenía menos de 38
Lower quartile: 25% tenía menos de 22
Whiskers: el otro 50%los componían personas de entre 0-22 y 38-60 más algunas personas de + de 60(outliers)
'''
# Out:
# '\nLa mediana se situa en 28 años aprox (la mitad tenía más de 28 y la otra mitad por debajo de 28 años)\nInter-quartile: el 50% de las personas tenían entre 22 y 38\nUpper quartile: el 75% tenía menos de 38\nLower quartile: 25% tenía menos de 22\nWhiskers: el otro 50%los componían personas de entre 0-22 y 38-60 más algunas personas de + de 60(outliers)\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
sns.distplot(titanic['Age'])

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment herea 
'''
a rasgos generales te da la misma info:
la media,donde se encuentra el 50%, outliers,etc
puedes ver mejor la distribución gracias a las bins
'''
# Out:
# '\na rasgos generales te da la misma info:\nmedia,donde se encuentra el 50%, outliers,etc\npuedes ver mejor la distribución gracias a las bins\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
sns.regplot(x=titanic['Fare'], y=titanic['Age'],data=titanic)

# %%
# your code-2nd way
#no se me ocurre...

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
sns.heatmap(titanic.corr())

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
#pClass and Fare

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
sns.boxplot(titanic['Pclass'],titanic['Age'])

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
g=sns.FacetGrid(titanic, col='Gender')
g = g.map(plt.hist, 'Age')
g
