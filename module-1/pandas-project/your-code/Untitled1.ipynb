# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/almu/ironhack/datamad0119/module-1/pandas-project/your-code/sharks.csv')

# %%
#confirmamos que no hay registros duplicados a priori
before = len(data)
data = data.drop_duplicates()
after = len(data)
before,after
# Out:
# (5992, 5992)

# %%
data.drop_duplicates('Case Number', keep=False,inplace=True)   #errooor
after = len(data)
after
# Out:
# 5960

# %%
data.dtypes
# Out:
# Case Number               object
# Date                      object
# Year                       int64
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                       object
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# pdf                       object
# href formula              object
# href                      object
# Case Number.1             object
# Case Number.2             object
# original order             int64
# Unnamed: 22               object
# Unnamed: 23               object
# dtype: object

# %%
data
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
#Cleaning. Missing values
null_cols = data.isnull().sum()
null_cols[null_cols > 0]
# Out:
# Country                     43
# Area                       399
# Location                   496
# Activity                   522
# Name                       198
# Sex                        566
# Age                       2664
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3192
# Species                   2917
# Investigator or Source      15
# href formula                 1
# href                         3
# Unnamed: 22               5959
# Unnamed: 23               5958
# dtype: int64

# %%
#Cleaning. Missing values. Eliminamos columnas con más de 4000 nulls
drop_cols = list(null_cols[null_cols > 4000].index)
data = data.drop(drop_cols, axis=1)

# %%
#eliminamos 'case number1' y 'case numer 2' porque no aportan info diferente a la columna de Date

data = data.drop(['Case Number.1','Case Number.2', 'Case Number'], axis=1)

# %%
#eliminamos columnas 'href formula','pdf','href' porque no interesan
drop_cols=['href formula','pdf','href',]
data = data.drop(drop_cols, axis=1)

# %%
set(data['Year']) #encontramos años con valor 0,55,77,500
# Out:
# {0,
#  5,
#  77,
#  500,
#  1543,
#  1554,
#  1555,
#  1580,
#  1595,
#  1617,
#  1637,
#  1638,
#  1642,
#  1700,
#  1703,
#  1721,
#  1733,
#  1738,
#  1742,
#  1748,
#  1749,
#  1755,
#  1758,
#  1764,
#  1767,
#  1771,
#  1776,
#  1779,
#  1785,
#  1787,
#  1788,
#  1791,
#  1800,
#  1803,
#  1804,
#  1805,
#  1807,
#  1811,
#  1812,
#  1816,
#  1817,
#  1818,
#  1819,
#  1822,
#  1825,
#  1826,
#  1827,
#  1828,
#  1829,
#  1830,
#  1831,
#  1832,
#  1834,
#  1835,
#  1836,
#  1837,
#  1839,
#  1840,
#  1841,
#  1842,
#  1844,
#  1845,
#  1846,
#  1847,
#  1848,
#  1849,
#  1850,
#  1851,
#  1852,
#  1853,
#  1854,
#  1855,
#  1856,
#  1858,
#  1859,
#  1860,
#  1861,
#  1862,
#  1863,
#  1864,
#  1865,
#  1866,
#  1867,
#  1868,
#  1869,
#  1870,
#  1871,
#  1872,
#  1873,
#  1874,
#  1875,
#  1876,
#  1877,
#  1878,
#  1879,
#  1880,
#  1881,
#  1882,
#  1883,
#  1884,
#  1885,
#  1886,
#  1887,
#  1888,
#  1889,
#  1890,
#  1891,
#  1892,
#  1893,
#  1894,
#  1895,
#  1896,
# ...

# %%
#eliminamos valores de la columna YEAR (año 5,500 y 77 son raros-no fiables al ser tan anitguos) (año 0 no aportan info).
#las filas que eliminamos solo suponen un 2% del total
#consideramos que no supone un problema de cara a sacar conclusiones sobre la BBDD.Eliminamos
data=data.drop(data[data.Year == 0].index);
data=data.drop(data[data.Year == 5].index);
data=data.drop(data[data.Year == 500].index);
data=data.drop(data[data.Year == 77].index);
data
# Out:
#                           Date  Year        Type                   Country  \
# 0                    18-Sep-16  2016  Unprovoked                       USA
# 1                    18-Sep-16  2016  Unprovoked                       USA
# 2                    18-Sep-16  2016  Unprovoked                       USA
# 3                    17-Sep-16  2016  Unprovoked                 AUSTRALIA
# 4                    16-Sep-16  2016  Unprovoked                 AUSTRALIA
# 5                    15-Sep-16  2016        Boat                 AUSTRALIA
# 6                    11-Sep-16  2016  Unprovoked                       USA
# 7                    07-Sep-16  2016  Unprovoked                       USA
# 8                    06-Sep-16  2016  Unprovoked             NEW CALEDONIA
# 9                    05-Sep-16  2016  Unprovoked                       USA
# 10                   05-Sep-16  2016  Unprovoked                 AUSTRALIA
# ...

# %%
#aparecen valores de ataques año 500, 77 y 5 no parecen muy fiables, los borramos

data
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
set(data['Country'])
# Out:
# {' PHILIPPINES',
#  ' TONGA',
#  'ADMIRALTY ISLANDS',
#  'ALGERIA',
#  'AMERICAN SAMOA',
#  'ANDAMAN / NICOBAR ISLANDAS',
#  'ANGOLA',
#  'ANTIGUA',
#  'ARGENTINA',
#  'ARUBA',
#  'ASIA?',
#  'ATLANTIC OCEAN',
#  'AUSTRALIA',
#  'AZORES',
#  'BAHAMAS',
#  'BAHREIN',
#  'BANGLADESH',
#  'BARBADOS',
#  'BAY OF BENGAL',
#  'BELIZE',
#  'BERMUDA',
#  'BRAZIL',
#  'BRITISH ISLES',
#  'BRITISH NEW GUINEA',
#  'BRITISH VIRGIN ISLANDS',
#  'BRITISH WEST INDIES',
#  'BURMA',
#  'Between PORTUGAL & INDIA',
#  'CANADA',
#  'CAPE VERDE',
#  'CARIBBEAN SEA',
#  'CAYMAN ISLANDS',
#  'CENTRAL PACIFIC',
#  'CEYLON (SRI LANKA)',
#  'CHILE',
#  'CHINA',
#  'COLUMBIA',
#  'COOK ISLANDS',
#  'COSTA RICA',
#  'CRETE',
#  'CROATIA',
#  'CUBA',
#  'CURACAO',
#  'CYPRUS',
#  'Coast of AFRICA',
#  'DIEGO GARCIA',
#  'DJIBOUTI',
#  'DOMINICAN REPUBLIC',
#  'ECUADOR',
#  'EGYPT',
#  'EGYPT ',
#  'EGYPT / ISRAEL',
#  'EL SALVADOR',
#  'ENGLAND',
#  'EQUATORIAL GUINEA / CAMEROON',
#  'FALKLAND ISLANDS',
# ...

# %%
set(data['Type'])     # relacionarlos con activity para ver q es
# Out:
# {'Boat', 'Boating', 'Invalid', 'Provoked', 'Sea Disaster', 'Unprovoked'}

# %%
set(data['Activity'])   #ES DE UTILIDAD ESTA COLUMNA?????
# Out:
# {nan,
#  'Surfing on air mattress',
#  'Swimming in strong current with 3 others when he disappeared',
#  'Swimming / surfing',
#  'Capsized fishing boat',
#  'Feeding mullet to sharks',
#  'USS Johnston DD 557 sunk on 10/24/1944 in the Battle off Samara. Crewmen were swimming beside a raft.',
#  'Swimming to mail boat',
#  'Swimming near anchored ship',
#  'Spearfishing using scuba & trailing a string of bleeding fish',
#  'Standing or boogie boardin',
#  'On inflatable raft',
#  'Swimming after his hat',
#  'Fishing for yellowtail',
#  'Free diving for abalone',
#  'Boat capsized, swimming ashore',
#  'Photographing fish',
#  'Swimming a quarter mile offshore',
#  'Free diving / modeling',
#  'Floating in tube',
#  'Sleeping in anchored boat',
#  'Washing his feet',
#  'Surfing, but treading water',
#  'Taking boat from California to Florida when it ran aground & he was swimming back to boat',
#  'Standing, holding shark pup',
#  'Helmet diving in Miami Seaquarium',
# ...

# %%
set(data['Area'])
# Out:
# {' Kikori River mouth',
#  ' La Libertad',
#  ' Lau Province',
#  ' Loyalty Islands',
#  ' Manila Bay',
#  ' New Jersey',
#  ' North Carolina',
#  ' Primorje-Gorski Kotar County',
#  ' Split-Dalmatia Count,',
#  ' Split-Dalmatia County',
#  '"Head of the Gulf"',
#  '(Southwestern Pacific)',
#  '04.05N-13.23W',
#  '1,000 miles east of Hawaii',
#  '1000 miles west of Hawaii',
#  '10∫S, 142∫E',
#  '12 miles off the north coast',
#  '150 miles offshore',
#  '165  miles from Bermuda',
#  '180 miles southeast of Okinawa',
#  '18S / 50E',
#  '19S, 178?E',
#  '2 to 3 miles off Taboguilla Island, Pacific Ocean',
#  '200 nm southeast of Manila',
#  '22∫N, 88∫E',
#  '25 km off the coast of Iran & 483km from mouth of Persian Gulf',
#  "250 miles southwest of O'ahu, Hawaii",
#  '30 nm from Singapore',
#  '300 miles east of Luzon',
#  '300 miles east of St. Thomas (Virgin Islands)',
#  '300 miles from Antigua',
#  '330 to 350 miles east of Wake Island',
#  '33N, 68W',
#  "35∫39 : 165∫8'",
# ...

# %%
set(data['Injury']) #ES DE UTILIDAD ESTA COLUMNA?????
# Out:
# {nan,
#  'Gaffed shark bit his ankle PROVOKED INCIDENT',
#  'Lacerations to his lower left leg, calf, foot & ankle',
#  'Thigh bitten, toes of left foot severed',
#  'Legs & buttocks bitten',
#  'Ankle bruised',
#  'Leg lacerated & bone fractured ',
#  ' Ankle lacerated',
#  'Laceration to right hand',
#  'Hooked shark bit his leg, knee to ankle PROVOKED INCIDENT',
#  '3" wound on thigh',
#  'Foot bitten by shark he was gaffing  PROVOKED INCIDENT',
#  "Fragment of human foot recovered from shark's gut",
#  'FATAL, legs severed  ',
#  'Knee lacerated',
#  'Legs & torso injured',
#  'FATAL, buttocks, lower abdomen & genitalia removed  ',
#  'Laceration to wrist',
#  'Navy personnel reported that his body was "mutilated by sharks" but it is probable that death resulted from drowning',
#  'Small laceration to head from captive shark',
#  'No injury, but shark damaged one of his swim fins',
#  'PRESUMED FATAL, body not recovered',
#  'Right hand bitten  PROVOKED INCIDENT',
# ...

# %%
#seleccionamos ataques recientes(si son antiguos la columna year no esta completa)

recent_data=data[(data['Year'].startswith('1')) & (data['Year'].startswith('2'))]
recent_data.head(5900)
#aparecen valores de ataques año 500, 77 y 5 no parecen muy fiables, los borramos
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-735c5e402a5d> in <module>
#       1 #seleccionamos ataques recientes(si son antiguos la columna year no esta completa)
#       2
# ----> 3 recent_data=data[(data['Year'].startswith('1')) & (data['Year'].startswith('2'))]
#       4 recent_data.head(5900)
#       5 #aparecen valores de ataques año 500, 77 y 5 no parecen muy fiables, los borramos
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'startswith'

# %%
# Out:
# Case Number               object
# Date                      object
# Year                      object
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                       object
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# original order             int64
# dtype: object
