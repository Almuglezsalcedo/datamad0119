# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. IMPORTING

# %%
data=pd.read_csv('/Users/almu/ironhack/datamad0119/module-1/pipelines-project/your-code/data-folder/googleplaystore.csv')

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %% [markdown]
# ## 2. WRANGLING

# %% [markdown]
# ### Eliminamos duplicados

# %%
before = len(data)
data = data.drop_duplicates()
after = len(data)
before,after
# Out:
# (10841, 10358)

# %% [markdown]
# ### Renombramos columnas

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data=data.rename(columns={'Content Rating':'Content_Rating', 'Last Updated':'Last_Updated','Current Ver':'Current_Ver','Android Ver':'Android_Ver'})

# %% [markdown]
# ### Comprobamos valores nulos

# %% [markdown]
# No eliminamos porque no hay muchos

# %%
null_cols = data.isnull().sum()
null_cols[null_cols > 0]
# Out:
# Rating            1465
# Type                 1
# Content_Rating       1
# Current_Ver          8
# Android_Ver          3
# dtype: int64

# %% [markdown]
# ### Eliminamos columnas innecesarias

# %% [markdown]
# 'Genres' contiene misma info que 'Category'

# %%
data=data.drop('Genres', axis=1)
data.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content_Rating        Last_Updated  \
# ...

# %% [markdown]
# ### Cambiamos data types

# %%
data.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content_Rating     object
# Last_Updated       object
# Current_Ver        object
# Android_Ver        object
# dtype: object

# %%
data['Last_Updated'] = data['Last_Updated'].astype('')
data.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     376             try:
# --> 377                 values, tz = conversion.datetime_to_datetime64(arg)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-57884e27f7c2> in <module>
# ----> 1 data['Last_Updated'] = data['Last_Updated'].astype('datetime64[ns]')
#       2 data.dtypes
#
# ...

# %%
data['Last_Updated'].value_counts()
# Out:
# August 3, 2018        298
# August 2, 2018        270
# July 31, 2018         269
# August 1, 2018        257
# July 30, 2018         195
# July 26, 2018         151
# July 25, 2018         144
# August 6, 2018        141
# July 27, 2018         137
# July 24, 2018         134
# July 23, 2018         121
# July 18, 2018         117
# July 19, 2018         112
# July 16, 2018         104
# July 11, 2018          97
# August 4, 2018         96
# July 12, 2018          96
# July 5, 2018           88
# July 17, 2018          88
# July 3, 2018           87
# July 9, 2018           85
# July 20, 2018          78
# July 13, 2018          77
# May 24, 2018           69
# July 6, 2018           61
# June 26, 2018          60
# June 27, 2018          57
# June 25, 2018          53
# May 25, 2018           53
# July 4, 2018           53
#                      ...
# January 10, 2016        1
# March 12, 2017          1
# September 22, 2011      1
# January 13, 2014        1
# ...
